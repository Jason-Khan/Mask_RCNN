# %% [markdown]
# # Mask R-CNN - Inspect Balloon Training Data
#
# Inspect and visualize data loading and pre-processing code.

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import itertools
import math
import logging
import json
import re
import random
from collections import OrderedDict
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.lines as lines
from matplotlib.patches import Polygon

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.barcode import barcode

# %matplotlib inline

# %% [markdown]
# ## Configurations
#
# Configurations are defined in balloon.py

# %%
config = barcode.BarcodeConfig()
BARCODE_DIR = os.path.join(ROOT_DIR, "../dataset/")

# %% [markdown]
# ## Dataset

# %%
# Load dataset
# Get the dataset from the releases page
# https://github.com/matterport/Mask_RCNN/releases
dataset = barcode.BarcodeDataset()
dataset.load_barcode(BARCODE_DIR, "train")

# Must call before using the dataset
dataset.prepare()

print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91183401 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96746896 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95004009 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99580441 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91853056 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90098064 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99002500 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89699841 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90916225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89529444 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94672900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93045316 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96845281 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90554256 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94439524 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89680900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89813529 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90954369 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91489225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93605625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98763844 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95648400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91604041 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92659876 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95570176 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93896100 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97140736 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94090000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92409769 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97990201 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94031809 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92679129 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90497169 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99082116 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91814724 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94556176 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99141849 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92948881 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98942809 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92640625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95082001 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93993025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96353856 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96510976 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91584900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92544400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95531076 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97456384 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92756161 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96079204 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91508356 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94848121 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95902849 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97042201 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92968164 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90003169 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98743969 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94828644 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94692361 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94245264 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91661476 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94420089 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89661961 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98724096 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99121936 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91757241 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94653441 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89965225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97693456 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99380961 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91623184 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93373569 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93954249 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92217609 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99201600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98664489 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94128804 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91776400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93799225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96864964 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90992521 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99920016 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98465929 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93760489 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99660289 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97515625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96963409 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96216481 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97495876 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95824521 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94400656 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90935296 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94322944 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99640324 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99241444 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90402064 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99062209 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92390544 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95394289 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89870400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90516196 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93508900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95199049 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91527489 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98604900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95257600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89491600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91891396 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98505625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99900025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99022401 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90250000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98168464 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90231001 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92910321 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90288004 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99740169 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95589729 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94148209 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91987281 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98287396 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94361796 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90649441 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96138025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96020401 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89832484 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90573289 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93876721 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93103201 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90022144 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91910569 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93586276 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97219600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96727225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95335696 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91030681 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90060100 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91565761 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90744676 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98089216 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96530625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89548369 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95101504 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90973444 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91298025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97259044 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90478144 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97634161 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95472441 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98704225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98903025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92813956 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94906564 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91164304 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92621376 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91240704 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89624089 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93547584 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97653924 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89908324 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98148649 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91929744 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98346889 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94809169 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98565184 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99500625 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95667961 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99620361 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93741124 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94284100 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93334921 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95883264 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92371321 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97911025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99520576 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98366724 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90611361 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94012416 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96825600 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98823481 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92160000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95687524 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99480676 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94750756 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99400900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99800100 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98863249 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95062500 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90630400 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90174016 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95804944 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90839961 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# ...
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96314596 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90421081 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92794689 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99420841 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93915481 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93064609 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92736900 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97337956 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89756676 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95746225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91470096 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95863681 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94225849 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90687529 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95491984 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95628841 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99221521 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93083904 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91202500 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97318225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94926049 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92448225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91699776 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91259809 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98426241 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97397161 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91968100 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93721761 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97061904 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94187025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98446084 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93276964 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98069409 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95961616 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91278916 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90383049 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93161104 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96687889 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90155025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99102025 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91049764 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92428996 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92833225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98029801 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93818596 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (89889361 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (90535225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (94206436 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92852496 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97752769 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99440784 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96294969 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96648561 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91872225 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (96609241 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98386561 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (97160449 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (91546624 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (92044836 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93141801 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (93238336 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (98624761 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99820081 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# Image Count: 80000
# Class Count: 2
#   0. BG
#   1. barcode

# %% [markdown]
# ## Display Samples
#
# Load and display images and masks.

# %%
# Load and display random samples
image_ids = np.random.choice(dataset.image_ids, 1)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# ## Bounding Boxes
#
# Rather than using bounding box coordinates provided by the source datasets, we compute the bounding boxes from masks instead. This allows us to handle bounding boxes consistently regardless of the source dataset, and it also makes it easier to resize, rotate, or crop images because we simply generate the bounding boxes from the updates masks rather than computing bounding box transformation for each type of image transformation.

# %%
# Load random image and mask.
image_id = random.choice(dataset.image_ids)
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id ", image_id, dataset.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id  18926 None
# image                    shape: (8301, 8301, 3)       min:    0.00000  max:  255.00000  uint8
# mask                     shape: (8301, 8301, 1)       min:    0.00000  max:    1.00000  bool
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min: 1328.00000  max: 5355.00000  int32

# %% [markdown]
# ## Resize Images
#
# To support multiple images per batch, images are resized to one size (1024x1024). Aspect ratio is preserved, though. If an image is not square, then zero padding is added at the top/bottom or right/left.

# %%
# Load random image and mask.
image_id = np.random.choice(dataset.image_ids, 1)[0]
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
original_shape = image.shape
# Resize
image, window, scale, padding, _ = utils.resize_image(
    image, 
    min_dim=config.IMAGE_MIN_DIM, 
    max_dim=config.IMAGE_MAX_DIM,
    mode=config.IMAGE_RESIZE_MODE)
mask = utils.resize_mask(mask, scale, padding)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id: ", image_id, dataset.image_reference(image_id))
print("Original shape: ", original_shape)
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id:  25115 None
# Original shape:  (8619, 8619, 3)
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# mask                     shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  bool
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:  359.00000  max:  652.00000  int32

# %% [markdown]
# ## Mini Masks
#
# Instance binary masks can get large when training with high resolution images. For example, if training with 1024x1024 image then the mask of a single instance requires 1MB of memory (Numpy uses bytes for boolean values). If an image has 100 instances then that's 100MB for the masks alone.
#
# To improve training speed, we optimize masks by:
# * We store mask pixels that are inside the object bounding box, rather than a mask of the full image. Most objects are small compared to the image size, so we save space by not storing a lot of zeros around the object.
# * We resize the mask to a smaller size (e.g. 56x56). For objects that are larger than the selected size we lose a bit of accuracy. But most object annotations are not very accuracy to begin with, so this loss is negligable for most practical purposes. Thie size of the mini_mask can be set in the config class.
#
# To visualize the effect of mask resizing, and to verify the code correctness, we visualize some examples.

# %%
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, use_mini_mask=False)

log("image", image)
log("image_meta", image_meta)
log("class_ids", class_ids)
log("bbox", bbox)
log("mask", mask)

display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])
# Out:
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  165.00000  uint8
# image_meta               shape: (14,)                 min:    0.00000  max: 47225.00000  float64
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:  128.00000  max:  896.00000  int32
# mask                     shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  bool

# %%
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %%
# Add augmentation and mask resizing.
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, augment=True, use_mini_mask=True)
log("mask", mask)
display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])
# Out:
# WARNING:root:'augment' is deprecated. Use 'augmentation' instead.
# mask                     shape: (56, 56, 1)           min:    0.00000  max:    1.00000  bool

# %%
mask = utils.expand_mask(bbox, mask, image.shape)
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %% [markdown]
# ## Anchors
#
# The order of anchors is important. Use the same order in training and prediction phases. And it must match the order of the convolution execution.
#
# For an FPN network, the anchors must be ordered in a way that makes it easy to match anchors to the output of the convolution layers that predict anchor scores and shifts.
# * Sort by pyramid level first. All anchors of the first level, then all of the second and so on. This makes it easier to separate anchors by level.
# * Within each level, sort anchors by feature map processing sequence. Typically, a convolution layer processes a feature map starting from top-left and moving right row by row.
# * For each feature map cell, pick any sorting order for the anchors of different ratios. Here we match the order of ratios passed to the function.
#
# **Anchor Stride:**
# In the FPN architecture, feature maps at the first few layers are high resolution. For example, if the input image is 1024x1024 then the feature meap of the first layer is 256x256, which generates about 200K anchors (256*256*3). These anchors are 32x32 pixels and their stride relative to image pixels is 4 pixels, so there is a lot of overlap. We can reduce the load significantly if we generate anchors for every other cell in the feature map. A stride of 2 will cut the number of anchors by 4, for example.
#
# In this implementation we use an anchor stride of 2, which is different from the paper.

# %%
# Generate Anchors
backbone_shapes = modellib.compute_backbone_shapes(config, config.IMAGE_SHAPE)
anchors = utils.generate_pyramid_anchors(config.RPN_ANCHOR_SCALES, 
                                          config.RPN_ANCHOR_RATIOS,
                                          backbone_shapes,
                                          config.BACKBONE_STRIDES, 
                                          config.RPN_ANCHOR_STRIDE)

# Print summary of anchors
num_levels = len(backbone_shapes)
anchors_per_cell = len(config.RPN_ANCHOR_RATIOS)
print("Count: ", anchors.shape[0])
print("Scales: ", config.RPN_ANCHOR_SCALES)
print("ratios: ", config.RPN_ANCHOR_RATIOS)
print("Anchors per Cell: ", anchors_per_cell)
print("Levels: ", num_levels)
anchors_per_level = []
for l in range(num_levels):
    num_cells = backbone_shapes[l][0] * backbone_shapes[l][1]
    anchors_per_level.append(anchors_per_cell * num_cells // config.RPN_ANCHOR_STRIDE**2)
    print("Anchors in Level {}: {}".format(l, anchors_per_level[l]))
# Out:
# Count:  261888
# Scales:  (32, 64, 128, 256, 512)
# ratios:  [0.5, 1, 2]
# Anchors per Cell:  3
# Levels:  5
# Anchors in Level 0: 196608
# Anchors in Level 1: 49152
# Anchors in Level 2: 12288
# Anchors in Level 3: 3072
# Anchors in Level 4: 768

# %% [markdown]
# Visualize anchors of one cell at the center of the feature map of a specific level.

# %%
## Visualize anchors of one cell at the center of the feature map of a specific level

# Load and draw random image
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, _, _, _ = modellib.load_image_gt(dataset, config, image_id)
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.imshow(image)
levels = len(backbone_shapes)

for level in range(levels):
    colors = visualize.random_colors(levels)
    # Compute the index of the anchors at the center of the image
    level_start = sum(anchors_per_level[:level]) # sum of anchors of previous levels
    level_anchors = anchors[level_start:level_start+anchors_per_level[level]]
    print("Level {}. Anchors: {:6}  Feature map Shape: {}".format(level, level_anchors.shape[0], 
                                                                  backbone_shapes[level]))
    center_cell = backbone_shapes[level] // 2
    center_cell_index = (center_cell[0] * backbone_shapes[level][1] + center_cell[1])
    level_center = center_cell_index * anchors_per_cell 
    center_anchor = anchors_per_cell * (
        (center_cell[0] * backbone_shapes[level][1] / config.RPN_ANCHOR_STRIDE**2) \
        + center_cell[1] / config.RPN_ANCHOR_STRIDE)
    level_center = int(center_anchor)

    # Draw anchors. Brightness show the order in the array, dark to bright.
    for i, rect in enumerate(level_anchors[level_center:level_center+anchors_per_cell]):
        y1, x1, y2, x2 = rect
        p = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=2, facecolor='none',
                              edgecolor=(i+1)*np.array(colors[level]) / anchors_per_cell)
        ax.add_patch(p)
# Out:
# Level 0. Anchors: 196608  Feature map Shape: [256 256]
# Level 1. Anchors:  49152  Feature map Shape: [128 128]
# Level 2. Anchors:  12288  Feature map Shape: [64 64]
# Level 3. Anchors:   3072  Feature map Shape: [32 32]
# Level 4. Anchors:    768  Feature map Shape: [16 16]

# %% [markdown]
# ## Data Generator

# %%
# Create data generator
random_rois = 2000
g = modellib.data_generator(
    dataset, config, shuffle=True, random_rois=random_rois, 
    batch_size=4,
    detection_targets=True)

# %%
# Uncomment to run the generator through a lot of images
# to catch rare errors
# for i in range(1000):
#     print(i)
#     _, _ = next(g)

# %%
# Get Next Image
if random_rois:
    [normalized_images, image_meta, rpn_match, rpn_bbox, gt_class_ids, gt_boxes, gt_masks, rpn_rois, rois], \
    [mrcnn_class_ids, mrcnn_bbox, mrcnn_mask] = next(g)
    
    log("rois", rois)
    log("mrcnn_class_ids", mrcnn_class_ids)
    log("mrcnn_bbox", mrcnn_bbox)
    log("mrcnn_mask", mrcnn_mask)
else:
    [normalized_images, image_meta, rpn_match, rpn_bbox, gt_boxes, gt_masks], _ = next(g)
    
log("gt_class_ids", gt_class_ids)
log("gt_boxes", gt_boxes)
log("gt_masks", gt_masks)
log("rpn_match", rpn_match, )
log("rpn_bbox", rpn_bbox)
image_id = modellib.parse_image_meta(image_meta)["image_id"][0]
print("image_id: ", image_id, dataset.image_reference(image_id))

# Remove the last dim in mrcnn_class_ids. It's only added
# to satisfy Keras restriction on target shape.
mrcnn_class_ids = mrcnn_class_ids[:,:,0]
# Out:
# rois                     shape: (4, 200, 4)           min:    0.00000  max: 1022.00000  int32
# mrcnn_class_ids          shape: (4, 200, 1)           min:    0.00000  max:    1.00000  int32
# mrcnn_bbox               shape: (4, 200, 2, 4)        min:   -3.64362  max:    3.60656  float32
# mrcnn_mask               shape: (4, 200, 28, 28, 2)   min:    0.00000  max:    1.00000  float32
# gt_class_ids             shape: (4, 100)              min:    0.00000  max:    1.00000  int32
# gt_boxes                 shape: (4, 100, 4)           min:    0.00000  max:  848.00000  int32
# gt_masks                 shape: (4, 56, 56, 100)      min:    0.00000  max:    1.00000  bool
# rpn_match                shape: (4, 261888, 1)        min:   -1.00000  max:    1.00000  int32
# rpn_bbox                 shape: (4, 256, 4)           min:   -1.98242  max:    1.88870  float64
# image_id:  31832 None

# %%
b = 0

# Restore original image (reverse normalization)
sample_image = modellib.unmold_image(normalized_images[b], config)

# Compute anchor shifts.
indices = np.where(rpn_match[b] == 1)[0]
refined_anchors = utils.apply_box_deltas(anchors[indices], rpn_bbox[b, :len(indices)] * config.RPN_BBOX_STD_DEV)
log("anchors", anchors)
log("refined_anchors", refined_anchors)

# Get list of positive anchors
positive_anchor_ids = np.where(rpn_match[b] == 1)[0]
print("Positive anchors: {}".format(len(positive_anchor_ids)))
negative_anchor_ids = np.where(rpn_match[b] == -1)[0]
print("Negative anchors: {}".format(len(negative_anchor_ids)))
neutral_anchor_ids = np.where(rpn_match[b] == 0)[0]
print("Neutral anchors: {}".format(len(neutral_anchor_ids)))

# ROI breakdown by class
for c, n in zip(dataset.class_names, np.bincount(mrcnn_class_ids[b].flatten())):
    if n:
        print("{:23}: {}".format(c[:20], n))

# Show positive anchors
fig, ax = plt.subplots(1, figsize=(16, 16))
visualize.draw_boxes(sample_image, boxes=anchors[positive_anchor_ids], 
                     refined_boxes=refined_anchors, ax=ax)
# Out:
# anchors                  shape: (261888, 4)           min: -362.03867  max: 1322.03867  float64
# refined_anchors          shape: (6, 4)                min:   77.00000  max:  782.00000  float32
# Positive anchors: 6
# Negative anchors: 250
# Neutral anchors: 261632
# BG                     : 134
# barcode                : 66

# %%
# Show negative anchors
visualize.draw_boxes(sample_image, boxes=anchors[negative_anchor_ids])

# %%
# Show neutral anchors. They don't contribute to training.
visualize.draw_boxes(sample_image, boxes=anchors[np.random.choice(neutral_anchor_ids, 100)])

# %% [markdown]
# ## ROIs

# %%
if random_rois:
    # Class aware bboxes
    bbox_specific = mrcnn_bbox[b, np.arange(mrcnn_bbox.shape[1]), mrcnn_class_ids[b], :]

    # Refined ROIs
    refined_rois = utils.apply_box_deltas(rois[b].astype(np.float32), bbox_specific[:,:4] * config.BBOX_STD_DEV)

    # Class aware masks
    mask_specific = mrcnn_mask[b, np.arange(mrcnn_mask.shape[1]), :, :, mrcnn_class_ids[b]]

    visualize.draw_rois(sample_image, rois[b], refined_rois, mask_specific, mrcnn_class_ids[b], dataset.class_names)
    
    # Any repeated ROIs?
    rows = np.ascontiguousarray(rois[b]).view(np.dtype((np.void, rois.dtype.itemsize * rois.shape[-1])))
    _, idx = np.unique(rows, return_index=True)
    print("Unique ROIs: {} out of {}".format(len(idx), rois.shape[1]))
# Out:
# Positive ROIs:  66
# Negative ROIs:  134
# Positive Ratio: 0.33
# Unique ROIs: 200 out of 200

# %%
if random_rois:
    # Dispalay ROIs and corresponding masks and bounding boxes
    ids = random.sample(range(rois.shape[1]), 8)

    images = []
    titles = []
    for i in ids:
        image = visualize.draw_box(sample_image.copy(), rois[b,i,:4].astype(np.int32), [255, 0, 0])
        image = visualize.draw_box(image, refined_rois[i].astype(np.int64), [0, 255, 0])
        images.append(image)
        titles.append("ROI {}".format(i))
        images.append(mask_specific[i] * 255)
        titles.append(dataset.class_names[mrcnn_class_ids[b,i]][:20])

    display_images(images, titles, cols=4, cmap="Blues", interpolation="none")

# %%
# Check ratio of positive ROIs in a set of images.
if random_rois:
    limit = 10
    temp_g = modellib.data_generator(
        dataset, config, shuffle=True, random_rois=10000, 
        batch_size=1, detection_targets=True)
    total = 0
    for i in range(limit):
        _, [ids, _, _] = next(temp_g)
        positive_rois = np.sum(ids[0] > 0)
        total += positive_rois
        print("{:5} {:5.2f}".format(positive_rois, positive_rois/ids.shape[1]))
    print("Average percent: {:.2f}".format(total/(limit*ids.shape[1])))
# Out:
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (95824521 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
#    66  0.33
#    66  0.33
#    66  0.33
# /home/ec2-user/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/PIL/Image.py:2766: DecompressionBombWarning: Image size (99820081 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
#    66  0.33
#    66  0.33
# Average percent: 0.33
