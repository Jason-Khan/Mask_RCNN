# %%
import skimage.io as io
import matplotlib.pyplot as plt

# %%
train = io.imread("train_90009.png")

# %%
plt.figure(figsize=(10, 10))
plt.imshow(train, cmap='gray')

# %%
predict = io.imread("predict_90009.png")

# %%
plt.figure(figsize=(10, 10))
plt.imshow(predict, cmap='gray')

# %%
offset = 2500
plt.imshow(train[offset:offset+400, offset:offset+400], cmap='gray')
